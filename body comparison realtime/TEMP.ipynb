# %%
import json
import numpy as np

# %%
file = "../bodies38.json"
with open(file, 'r') as fp:
    motion_data = json.load(fp)

# %%
ref_frames = list(motion_data.values())

# %%
ref_times = np.array([f['timestamp'] for f in ref_frames])
ref_times -= ref_times[0]
ref_times / 1e9
# Out:
# array([ 0.      ,  0.199999,  0.250052,  0.316661,  0.366629,  0.416631,
#         0.466658,  0.51665 ,  0.566753,  0.633373,  0.683385,  0.733484,
#         0.766667,  0.816625,  0.866703,  0.916625,  0.966652,  1.016779,
#         1.066867,  1.116751,  1.166763,  1.216781,  1.266775,  1.316752,
#         1.366757,  1.399997,  1.449996,  1.499996,  1.550005,  1.600075,
#         1.650147,  1.700124,  1.750134,  1.783376,  1.833375,  1.883372,
#         1.933372,  1.983401,  2.033398,  2.083487,  2.133379,  2.183373,
#         2.216744,  2.266749,  2.316749,  2.366893,  2.416751,  2.46675 ,
#         2.516746,  2.55012 ,  2.600121,  2.650124,  2.700164,  2.750123,
#         2.800124,  2.850131,  2.883506,  2.933496,  2.983502,  3.033507,
#         3.083496,  3.133501,  3.183504,  3.233513,  3.283536,  3.333532,
#         3.383532,  3.433543,  3.483504,  3.533534,  3.583496,  3.6335  ,
#         3.683522,  3.733507,  3.80025 ,  3.850246,  3.900268,  3.950253,
# ...
